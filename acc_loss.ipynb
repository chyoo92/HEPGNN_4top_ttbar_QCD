# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
import glob
uni = "210914"

path = "/users/yewzzang/work/HEPGNN_4top/result/*" + uni +"*/train.csv"
train_path = glob.glob(path)
train_list = [file for file in train_path if file.endswith(".csv")]




path = "/users/yewzzang/work/HEPGNN_4top/result/*"+uni +"*/*"+uni +"*.csv"
pred_path = glob.glob(path)
pred_list = [file for file in pred_path if file.endswith(".csv")]





d = train_list
dd = pred_list

# %%
# d = [
#     '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_2l/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_2l/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_2l/train.csv',
#       ]
# dd = [
#     '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea/210813_QCD_ttbar_4fea.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_2l/210813_QCD_ttbar_4fea_2l.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea/210813_QCD_4top_4fea.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_2l/210813_QCD_4top_4fea_2l.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea/210813_ttbar_4top_4fea.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_2l/210813_ttbar_4top_4fea_2l.csv',
#       ]
# ddd = [
#        'no_edge_QCD_ttbar_4fea',
#        'no_edge_QCD_ttbar_4fea_2l',
#        'no_edge_QCD_4top_4fea',
#        'no_edge_QCD_4top_4fea_2l',
#        'no_edge_ttbar_4top_4fea',
#        'no_edge_ttbar_4top_4fea_2l',
 
#       ]

# %%
# d = [
#     '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_2l_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_2l_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_2l_sm_lr5/train.csv',
#       ]
# dd = [
#     '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_sm_lr5/210817_QCD_ttbar_4fea_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_2l_sm_lr5/210817_QCD_ttbar_4fea_2l_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_sm_lr5/210817_QCD_4top_4fea_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_2l_sm_lr5/210817_QCD_4top_4fea_2l_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_sm_lr5/210817_ttbar_4top_4fea_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_2l_sm_lr5/210817_ttbar_4top_4fea_2l_sm_lr5.csv',
#       ]
# ddd = [
#        'no_edge_QCD_ttbar_4fea_sm_lr5',
#        'no_edge_QCD_ttbar_4fea_sm_lr5_2l',
#        'no_edge_QCD_4top_4fea_sm_lr5',
#        'no_edge_QCD_4top_4fea_sm_lr5_2l',
#        'no_edge_ttbar_4top_4fea_sm_lr5',
#        'no_edge_ttbar_4top_4fea_sm_lr5_2l',
 
#       ]

# %%
# d = [
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_ttbar/train.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_ttbar_2layer/train.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_4top/train.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_4top_2layer/train.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_ttbar_4top/train.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_ttbar_4top_2layer/train.csv',
#         '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_2l/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_2l/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_2l/train.csv',
#         '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_sm_lr/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_2l_sm_lr/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_sm_lr/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_2l_sm_lr/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_sm_lr/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_2l_sm_lr/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_2l_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_2l_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_sm_lr5/train.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_2l_sm_lr5/train.csv',

# ]
# dd = [
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_ttbar/210727_QCD_ttbar.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_ttbar_2layer/210727_QCD_ttbar_2layer.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_4top/210727_QCD_4top.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_QCD_4top_2layer/210727_QCD_4top_2layer.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_ttbar_4top/210727_ttbar_4top.csv',
# #       '/users/yewzzang/work/HEPGNN_4top/result/210727_ttbar_4top_2layer/210727_ttbar_4top_2layer.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea/210813_QCD_ttbar_4fea.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_2l/210813_QCD_ttbar_4fea_2l.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea/210813_QCD_4top_4fea.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_2l/210813_QCD_4top_4fea_2l.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea/210813_ttbar_4top_4fea.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_2l/210813_ttbar_4top_4fea_2l.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_sm_lr/210813_QCD_ttbar_4fea_sm_lr.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_ttbar_4fea_2l_sm_lr/210813_QCD_ttbar_4fea_2l_sm_lr.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_sm_lr/210813_QCD_4top_4fea_sm_lr.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_QCD_4top_4fea_2l_sm_lr/210813_QCD_4top_4fea_2l_sm_lr.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_sm_lr/210813_ttbar_4top_4fea_sm_lr.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210813_ttbar_4top_4fea_2l_sm_lr/210813_ttbar_4top_4fea_2l_sm_lr.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_sm_lr5/210817_QCD_ttbar_4fea_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_ttbar_4fea_2l_sm_lr5/210817_QCD_ttbar_4fea_2l_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_sm_lr5/210817_QCD_4top_4fea_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_QCD_4top_4fea_2l_sm_lr5/210817_QCD_4top_4fea_2l_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_sm_lr5/210817_ttbar_4top_4fea_sm_lr5.csv',
#       '/users/yewzzang/work/HEPGNN_4top/result/210817_ttbar_4top_4fea_2l_sm_lr5/210817_ttbar_4top_4fea_2l_sm_lr5.csv',

#       ]
# ddd = [
# #        'no_edge_QCD_ttbar',
# #        'no_edge_QCD_ttbar_2l',
# #        'no_edge_QCD_4top',
# #        'no_edge_QCD_4top_2l',
# #        'no_edge_ttbar_4top',
# #        'no_edge_ttbar_4top_2l',
#        'no_edge_QCD_ttbar_4fea',
#        'no_edge_QCD_ttbar_4fea_2l',
#        'no_edge_QCD_4top_4fea',
#        'no_edge_QCD_4top_4fea_2l',
#        'no_edge_ttbar_4top_4fea',
#        'no_edge_ttbar_4top_4fea_2l',
#        'no_edge_QCD_ttbar_4fea_sm_lr',
#        'no_edge_QCD_ttbar_4fea_sm_lr_2l',
#        'no_edge_QCD_4top_4fea_sm_lr',
#        'no_edge_QCD_4top_4fea_sm_lr_2l',
#        'no_edge_ttbar_4top_4fea_sm_lr',
#        'no_edge_ttbar_4top_4fea_sm_lr_2l',
#        'no_edge_QCD_ttbar_4fea_sm_lr5',
#        'no_edge_QCD_ttbar_4fea_sm_lr5_2l',
#        'no_edge_QCD_4top_4fea_sm_lr5',
#        'no_edge_QCD_4top_4fea_sm_lr5_2l',
#        'no_edge_ttbar_4top_4fea_sm_lr5',
#        'no_edge_ttbar_4top_4fea_sm_lr5_2l',
 
#       ]

# %%
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 5
plt.rcParams["legend.loc"] = 'upper right'
plt.rcParams["legend.frameon"] = False
plt.rcParams["legend.loc"] = 'upper left'

# %%
plt.rcParams['figure.figsize'] = (10, 10)
# plt.rcParams['figure.figsize'] = (10, 10)
ax1 = plt.subplot(3, 2, 1, yscale='log', ylabel='Loss(train)', xlabel='epoch')
ax2 = plt.subplot(3, 2, 2, yscale='log', ylabel='Loss(val)', xlabel='epoch')
# ax1 = plt.subplot(3, 2, 1, ylabel='Loss(train)', xlabel='epoch')
# ax2 = plt.subplot(3, 2, 2, ylabel='Loss(val)', xlabel='epoch')
ax3 = plt.subplot(3, 2, 3, ylabel='Accuracy(train)', xlabel='epoch')
ax4 = plt.subplot(3, 2, 4, ylabel='Accuracy(val)', xlabel='epoch')
# ax1.set_ylim([0, 100])
# ax2.set_ylim([0, 100])
ax3.set_ylim([0.55,1.1])
ax4.set_ylim([0.55,1.1])
for ax in (ax1, ax2, ax3, ax4):
    ax.grid(which='major', axis='both', linestyle='-.')
    ax.grid(which='minor', linestyle=':')
    ax.set_xlim([0,200])
lines, labels = [], []

for i in range(len(d)):
    df = pd.read_csv(d[i])
    
    label = d[i].split('/')[-2].replace('__', ' ')
    if label.split('_')[0] == '210817':
        l =  ax1.plot(df['loss'], linewidth=2)
        ax2.plot(df['val_loss'], linewidth=2)
        ax3.plot(df['acc'], linewidth=2)
        ax4.plot(df['val_acc'], linewidth=2)
    else:
        l =  ax1.plot(df['loss'])
        ax2.plot(df['val_loss'])
        ax3.plot(df['acc'])
        ax4.plot(df['val_acc'])
    
    
    
    
#     label = ddd[i]
    
    
    
    
    lines.append(l[0])
    labels.append(label)
ax5 = plt.subplot(3,1,3)
ax5.legend(lines, labels)
# ax5.legend(lines, labels, bbox_to_anchor=(1.1, -4, 7, 7))
ax5.axis('off')
plt.tight_layout()
# plt.savefig('acc_loss.png',dpi=300)
plt.show()
plt.close()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


#plt.yscale('log')
plt.figure(figsize=(10,10))
for i in range(len(dd)):
    df = pd.read_csv(dd[i])
    tpr, fpr, thr = roc_curve(df['label'], df['prediction'], sample_weight=df['scaledWeight'], pos_label=0)
    try:
        auc = roc_auc_score(df['label'], df['prediction'], sample_weight=df['scaledWeight'])
    except:
        aaa = 0 
        for j in range(len(fpr)):
            if j == 0:
                aa = tpr[j]*(fpr[j]-0)
            else:
                aa = tpr[j]*(fpr[j]-fpr[j-1])
            aaa = aaa + aa
        auc = aaa



#     plt.plot(fpr, tpr, label=dd[i].split('/')[-2].replace('__', ' ')+'  AUC = %.3f' % (auc))
    if dd[i].split('/')[-2].replace('__', ' ').split('_')[0] == '210727':
        plt.plot(fpr, tpr, label='AUC = %.3f' % (auc) + '   ' +ddd[i], linewidth='2')
    else:
        plt.plot(fpr, tpr, label='AUC = %.3f' % (auc) + '   ' +ddd[i])
        
        
    plt.xlabel('FN efficiency')
    plt.ylabel('ME efficiency')
    #plt.xlim(0, 0.001)
    plt.xlim(0, 1.000)
    plt.ylim(0, 1.050)
    plt.legend(loc = 'lower right',fontsize=12)
#     plt.legend(bbox_to_anchor=(1.1, -14, 15, 15))
    # plt.savefig('result/' +args.output + '/' + args.output + '_efficiency.png', dpi=300)
    plt.grid()
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/pytorch170_pyG/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-2d5ffad6cce0> in <module>
# ...
